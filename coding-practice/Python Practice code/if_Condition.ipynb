# %%
india = ["mumbai", "banglore", "chennai", "delhi"]
pakistan = ["lahore","karachi","islamabad"]
bangladesh = ["dhaka", "khulna", "rangpur"]

#Write a program that asks user to enter a city name and it should tell which country the city belongs to
city = input("Enter a city:")
if city in india:
  print("India")
elif city in pakistan:
  print("Pakistan")
else:
  print("bangladesh")
# Out:
# Enter a city:dhaka
# bangladesh

# %%
# Write a program that asks user to enter two cities and it tells you
# if they both are in same country or not. For example if I enter mumbai and
# chennai, it will print "Both cities are in India" but if I enter mumbai and
# dhaka it should print "They don't belong to same country"

city1 = input("Enter the city 1:")
city2 = input("Enter the city 2:")

if city1 in india and city2 in india:
  print("Both cities are in India")
elif city1 in pakistan and city2 in pakistan:
  print("Both cities are in pakistan")
elif city1 in bangladesh and city2 in bangladesh:
  print("Both cities are in bangladesh")
else:
  print("They don't belong to same country")
# Out:
# Enter the city 1:banglore
# Enter the city 2:dhaka
# They don't belong to same country

# %%
# Write a python program that can tell you if your sugar is normal or not. Normal fasting level sugar range is 80 to 100.
# Ask user to enter his fasting sugar level
# If it is below 80 to 100 range then print that sugar is low
# If it is above 100 then print that it is high otherwise print that it is normal

sugar_level = input("Please enter your sugar level: ")
sugar = float(sugar_level)
if sugar<80:
  print("Your sugar is low")
elif sugar >100:
  print("Your sugar is high")
else:
  print("Your sugar in normal")
# Out:
# Please enter your sugar level: 120
# Your sugar is high
