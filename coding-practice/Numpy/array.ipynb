# %%
import numpy as np
import time
import sys
l = range(1000)
print(sys.getsizeof(5)*1000)
array = np.arange(1000)
print(array.size*array.itemsize)
# Out:
# 28000
# 8000

# %%
SIZE = 1000
l1 = range(SIZE)
l2 = range(SIZE)

a1 = np.arange(SIZE)
a2 = np.arange(SIZE)

#Python List
start = time.time()
result = [(x+y) for x,y in zip (l1,l2)]
print("Python list took:", (time.time()-start)*1000)

# Numpy array
start = time.time()
result = a1 + a2
print("numpy took: ",(time.time()-start)*1000)
# Out:
# Python list took: 0.45609474182128906
# numpy took:  0.1914501190185547
